# %%
# https://rare-technologies.com/word2vec-tutorial/
import gensim, logging, os
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
 
other_sentences = [['first', 'sentence'], ['second', 'sentence']]
# train word2vec on the two other_sentences
model = gensim.models.Word2Vec(other_sentences, min_count=1)

class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname
 
    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield line.split()
 
some_sentences = list(MySentences('yezheng_test/')) # a memory-friendly iterator
model = gensim.models.Word2Vec(some_sentences)
# Out:
# 2018-02-03 06:10:49,549 : INFO : collecting all words and their counts
# 2018-02-03 06:10:49,550 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-02-03 06:10:49,551 : INFO : collected 3 word types from a corpus of 4 raw words and 2 sentences
# 2018-02-03 06:10:49,551 : INFO : Loading a fresh vocabulary
# 2018-02-03 06:10:49,553 : INFO : min_count=1 retains 3 unique words (100% of original 3, drops 0)
# 2018-02-03 06:10:49,554 : INFO : min_count=1 leaves 4 word corpus (100% of original 4, drops 0)
# 2018-02-03 06:10:49,555 : INFO : deleting the raw counts dictionary of 3 items
# 2018-02-03 06:10:49,557 : INFO : sample=0.001 downsamples 3 most-common words
# 2018-02-03 06:10:49,558 : INFO : downsampling leaves estimated 0 word corpus (5.7% of prior 4)
# 2018-02-03 06:10:49,560 : INFO : estimated required memory for 3 words and 100 dimensions: 3900 bytes
# 2018-02-03 06:10:49,561 : INFO : resetting layer weights
# 2018-02-03 06:10:49,563 : INFO : training model with 3 workers on 3 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-02-03 06:10:49,567 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-02-03 06:10:49,569 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-02-03 06:10:49,570 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-02-03 06:10:49,571 : INFO : training on 20 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-02-03 06:10:49,573 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2018-02-03 06:10:49,582 : INFO : collecting all words and their counts
# 2018-02-03 06:10:49,583 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-02-03 06:10:49,587 : INFO : collected 2694 word types from a corpus of 6891 raw words and 363 sentences
# 2018-02-03 06:10:49,590 : INFO : Loading a fresh vocabulary
# 2018-02-03 06:10:49,594 : INFO : min_count=5 retains 177 unique words (6% of original 2694, drops 2517)
# 2018-02-03 06:10:49,595 : INFO : min_count=5 leaves 2239 word corpus (32% of original 6891, drops 4652)
# 2018-02-03 06:10:49,598 : INFO : deleting the raw counts dictionary of 2694 items
# 2018-02-03 06:10:49,600 : INFO : sample=0.001 downsamples 118 most-common words
# 2018-02-03 06:10:49,601 : INFO : downsampling leaves estimated 1136 word corpus (50.8% of prior 2239)
# 2018-02-03 06:10:49,603 : INFO : estimated required memory for 177 words and 100 dimensions: 230100 bytes
# 2018-02-03 06:10:49,605 : INFO : resetting layer weights
# 2018-02-03 06:10:49,610 : INFO : training model with 3 workers on 177 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-02-03 06:10:49,625 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-02-03 06:10:49,628 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-02-03 06:10:49,630 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-02-03 06:10:49,631 : INFO : training on 34455 raw words (5601 effective words) took 0.0s, 504900 effective words/s
# 2018-02-03 06:10:49,632 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
model = gensim.models.Word2Vec(iter=1)  # an empty model, no training yet
model.build_vocab(some_sentences)  # can be a non-repeatable, 1-pass generator
other_sentences = [['first', 'sentence'], ['second', 'sentence']]
model.train(other_sentences,total_examples=model.corpus_count,epochs=model.iter)   # can be a non-repeatable, 1-pass generator
# You must specify an explict epochs count. The usual value is epochs=model.iter.
# https://github.com/llSourcell/word_vectors_game_of_thrones-LIVE/issues/7
# Out:
# 2018-02-03 06:10:49,646 : INFO : collecting all words and their counts
# 2018-02-03 06:10:49,648 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-02-03 06:10:49,652 : INFO : collected 2694 word types from a corpus of 6891 raw words and 363 sentences
# 2018-02-03 06:10:49,653 : INFO : Loading a fresh vocabulary
# 2018-02-03 06:10:49,656 : INFO : min_count=5 retains 177 unique words (6% of original 2694, drops 2517)
# 2018-02-03 06:10:49,658 : INFO : min_count=5 leaves 2239 word corpus (32% of original 6891, drops 4652)
# 2018-02-03 06:10:49,661 : INFO : deleting the raw counts dictionary of 2694 items
# 2018-02-03 06:10:49,662 : INFO : sample=0.001 downsamples 118 most-common words
# 2018-02-03 06:10:49,663 : INFO : downsampling leaves estimated 1136 word corpus (50.8% of prior 2239)
# 2018-02-03 06:10:49,665 : INFO : estimated required memory for 177 words and 100 dimensions: 230100 bytes
# 2018-02-03 06:10:49,667 : INFO : resetting layer weights
# 2018-02-03 06:10:49,672 : INFO : training model with 3 workers on 177 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-02-03 06:10:49,675 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-02-03 06:10:49,676 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-02-03 06:10:49,677 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-02-03 06:10:49,678 : INFO : training on 4 raw words (0 effective words) took 0.0s, 0 effective words/s
# 2018-02-03 06:10:49,679 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2018-02-03 06:10:49,681 : WARNING : supplied example count (2) did not equal expected count (363)
# 0

# %%
# print(some_sentences)
# print(other_sentences)

# %%
# Word2vec accepts several parameters that affect both training speed and quality.
model = gensim.models.Word2Vec(some_sentences, min_count=10)  # default value is 5
model = gensim.models.Word2Vec(some_sentences, size=200)  # default value is 100
model = gensim.models.Word2Vec(some_sentences, workers=4) # default = 1 worker = no parallelization
model = gensim.models.Word2Vec(some_sentences, min_count=10, size = 200, workers=4)
# Out:
# 2018-02-03 06:15:05,334 : INFO : collecting all words and their counts
# 2018-02-03 06:15:05,338 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-02-03 06:15:05,353 : INFO : collected 2694 word types from a corpus of 6891 raw words and 363 sentences
# 2018-02-03 06:15:05,357 : INFO : Loading a fresh vocabulary
# 2018-02-03 06:15:05,362 : INFO : min_count=10 retains 35 unique words (1% of original 2694, drops 2659)
# 2018-02-03 06:15:05,364 : INFO : min_count=10 leaves 1382 word corpus (20% of original 6891, drops 5509)
# 2018-02-03 06:15:05,366 : INFO : deleting the raw counts dictionary of 2694 items
# 2018-02-03 06:15:05,368 : INFO : sample=0.001 downsamples 35 most-common words
# 2018-02-03 06:15:05,375 : INFO : downsampling leaves estimated 248 word corpus (18.0% of prior 1382)
# 2018-02-03 06:15:05,376 : INFO : estimated required memory for 35 words and 100 dimensions: 45500 bytes
# 2018-02-03 06:15:05,379 : INFO : resetting layer weights
# 2018-02-03 06:15:05,386 : INFO : training model with 3 workers on 35 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-02-03 06:15:05,408 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-02-03 06:15:05,410 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-02-03 06:15:05,417 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-02-03 06:15:05,419 : INFO : training on 34455 raw words (1212 effective words) took 0.0s, 68001 effective words/s
# 2018-02-03 06:15:05,420 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2018-02-03 06:15:05,422 : INFO : collecting all words and their counts
# 2018-02-03 06:15:05,424 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-02-03 06:15:05,428 : INFO : collected 2694 word types from a corpus of 6891 raw words and 363 sentences
# 2018-02-03 06:15:05,430 : INFO : Loading a fresh vocabulary
# 2018-02-03 06:15:05,434 : INFO : min_count=5 retains 177 unique words (6% of original 2694, drops 2517)
# 2018-02-03 06:15:05,436 : INFO : min_count=5 leaves 2239 word corpus (32% of original 6891, drops 4652)
# 2018-02-03 06:15:05,439 : INFO : deleting the raw counts dictionary of 2694 items
# 2018-02-03 06:15:05,440 : INFO : sample=0.001 downsamples 118 most-common words
# 2018-02-03 06:15:05,442 : INFO : downsampling leaves estimated 1136 word corpus (50.8% of prior 2239)
# 2018-02-03 06:15:05,443 : INFO : estimated required memory for 177 words and 200 dimensions: 371700 bytes
# 2018-02-03 06:15:05,445 : INFO : resetting layer weights
# 2018-02-03 06:15:05,452 : INFO : training model with 3 workers on 177 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-02-03 06:15:05,470 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-02-03 06:15:05,472 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-02-03 06:15:05,473 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-02-03 06:15:05,474 : INFO : training on 34455 raw words (5646 effective words) took 0.0s, 425689 effective words/s
# 2018-02-03 06:15:05,475 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2018-02-03 06:15:05,477 : INFO : collecting all words and their counts
# 2018-02-03 06:15:05,478 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-02-03 06:15:05,483 : INFO : collected 2694 word types from a corpus of 6891 raw words and 363 sentences
# 2018-02-03 06:15:05,484 : INFO : Loading a fresh vocabulary
# 2018-02-03 06:15:05,489 : INFO : min_count=5 retains 177 unique words (6% of original 2694, drops 2517)
# 2018-02-03 06:15:05,490 : INFO : min_count=5 leaves 2239 word corpus (32% of original 6891, drops 4652)
# 2018-02-03 06:15:05,492 : INFO : deleting the raw counts dictionary of 2694 items
# 2018-02-03 06:15:05,494 : INFO : sample=0.001 downsamples 118 most-common words
# 2018-02-03 06:15:05,495 : INFO : downsampling leaves estimated 1136 word corpus (50.8% of prior 2239)
# 2018-02-03 06:15:05,496 : INFO : estimated required memory for 177 words and 100 dimensions: 230100 bytes
# 2018-02-03 06:15:05,498 : INFO : resetting layer weights
# 2018-02-03 06:15:05,506 : INFO : training model with 4 workers on 177 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-02-03 06:15:05,517 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-02-03 06:15:05,523 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-02-03 06:15:05,525 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-02-03 06:15:05,526 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-02-03 06:15:05,527 : INFO : training on 34455 raw words (5660 effective words) took 0.0s, 385617 effective words/s
# 2018-02-03 06:15:05,529 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2018-02-03 06:15:05,530 : INFO : collecting all words and their counts
# 2018-02-03 06:15:05,532 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2018-02-03 06:15:05,537 : INFO : collected 2694 word types from a corpus of 6891 raw words and 363 sentences
# 2018-02-03 06:15:05,538 : INFO : Loading a fresh vocabulary
# 2018-02-03 06:15:05,543 : INFO : min_count=10 retains 35 unique words (1% of original 2694, drops 2659)
# 2018-02-03 06:15:05,544 : INFO : min_count=10 leaves 1382 word corpus (20% of original 6891, drops 5509)
# 2018-02-03 06:15:05,546 : INFO : deleting the raw counts dictionary of 2694 items
# 2018-02-03 06:15:05,548 : INFO : sample=0.001 downsamples 35 most-common words
# 2018-02-03 06:15:05,550 : INFO : downsampling leaves estimated 248 word corpus (18.0% of prior 1382)
# 2018-02-03 06:15:05,551 : INFO : estimated required memory for 35 words and 200 dimensions: 73500 bytes
# 2018-02-03 06:15:05,553 : INFO : resetting layer weights
# 2018-02-03 06:15:05,556 : INFO : training model with 4 workers on 35 vocabulary and 200 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2018-02-03 06:15:05,589 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2018-02-03 06:15:05,591 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2018-02-03 06:15:05,592 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2018-02-03 06:15:05,594 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2018-02-03 06:15:05,596 : INFO : training on 34455 raw words (1268 effective words) took 0.0s, 55268 effective words/s
# 2018-02-03 06:15:05,598 : WARNING : under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay

# %%
from gensim.models import KeyedVectors
vecfile = 'data/GoogleNews-vectors-negative300.filter'
vecs = KeyedVectors.load_word2vec_format(vecfile, binary=True)
# Out:
# 2018-02-03 07:05:33,182 : INFO : loading projection weights from data/GoogleNews-vectors-negative300.filter
# 2018-02-03 07:05:33,214 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,215 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,216 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,218 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,220 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,221 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,223 : WARNING : duplicate word '12' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,229 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,230 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,231 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,235 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,236 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,239 : WARNING : duplicate word '9' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,240 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,241 : WARNING : duplicate word '125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,243 : WARNING : duplicate word '21875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,244 : WARNING : duplicate word '.12597656' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,245 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,246 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,248 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,251 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,252 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,254 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,256 : WARNING : duplicate word '421875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,257 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,259 : WARNING : duplicate word '125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,260 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,261 : WARNING : duplicate word '953' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,264 : WARNING : duplicate word '171875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,266 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,268 : WARNING : duplicate word '88' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,269 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,271 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,272 : WARNING : duplicate word '941406' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,273 : WARNING : duplicate word '6875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,275 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,276 : WARNING : duplicate word '6875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,277 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,278 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,279 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,281 : WARNING : duplicate word '1' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,285 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,286 : WARNING : duplicate word '018554688' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,287 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,289 : WARNING : duplicate word '12' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,290 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,291 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,293 : WARNING : duplicate word '753906' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,294 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,295 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,296 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,297 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,298 : WARNING : duplicate word '14' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,302 : WARNING : duplicate word '7' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,303 : WARNING : duplicate word '4688' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,304 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,305 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,307 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,308 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,310 : WARNING : duplicate word '12' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,311 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,312 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,313 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,314 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,315 : WARNING : duplicate word '12' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,316 : WARNING : duplicate word '281' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,318 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,319 : WARNING : duplicate word '3125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,320 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,322 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,324 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,325 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,326 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,327 : WARNING : duplicate word '9' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,328 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,329 : WARNING : duplicate word '48438' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,330 : WARNING : duplicate word '88' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,332 : WARNING : duplicate word '625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,334 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,335 : WARNING : duplicate word '769531' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,337 : WARNING : duplicate word '875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,338 : WARNING : duplicate word '38' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,339 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,340 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,341 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,343 : WARNING : duplicate word '6875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,344 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,345 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,347 : WARNING : duplicate word '19' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,348 : WARNING : duplicate word '0.12597656' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,349 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,351 : WARNING : duplicate word '8438' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,352 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,353 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,357 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,358 : WARNING : duplicate word '7' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,359 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,360 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,361 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,363 : WARNING : duplicate word '19' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,364 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,368 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,386 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,398 : WARNING : duplicate word '125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,399 : WARNING : duplicate word '625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,400 : WARNING : duplicate word '62' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,402 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,404 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,406 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,407 : WARNING : duplicate word '14' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,408 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,409 : WARNING : duplicate word '15625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,410 : WARNING : duplicate word '19' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,412 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,413 : WARNING : duplicate word '38' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,417 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,419 : WARNING : duplicate word '625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,424 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,425 : WARNING : duplicate word '69' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,426 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,430 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,431 : WARNING : duplicate word '69' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,432 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,437 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,438 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,440 : WARNING : duplicate word '.12597656' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,444 : WARNING : duplicate word '88' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,446 : WARNING : duplicate word '34375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,447 : WARNING : duplicate word '.04321289' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,449 : WARNING : duplicate word '14453125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,452 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,454 : WARNING : duplicate word '125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,456 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,457 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,459 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,461 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,462 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,463 : WARNING : duplicate word '0.087890625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,466 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,470 : WARNING : duplicate word '214844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,471 : WARNING : duplicate word '1875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,473 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,474 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,475 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,477 : WARNING : duplicate word '875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,478 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,479 : WARNING : duplicate word '3125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,480 : WARNING : duplicate word '1777344' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,481 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,484 : WARNING : duplicate word '0.28515625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,486 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,487 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,488 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,489 : WARNING : duplicate word '31' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,491 : WARNING : duplicate word '28' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,492 : WARNING : duplicate word '312' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,493 : WARNING : duplicate word '8642578' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,494 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,496 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,497 : WARNING : duplicate word '9844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,499 : WARNING : duplicate word '0469' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,501 : WARNING : duplicate word '40625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,503 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,505 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,506 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,507 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,508 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,510 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,511 : WARNING : duplicate word '06' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,513 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,514 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,515 : WARNING : duplicate word '62' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,517 : WARNING : duplicate word '19' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,518 : WARNING : duplicate word '6406' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,519 : WARNING : duplicate word '54688' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,521 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,522 : WARNING : duplicate word '38' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,523 : WARNING : duplicate word '31' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,524 : WARNING : duplicate word '312' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,525 : WARNING : duplicate word '3281' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,526 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,528 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,531 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,533 : WARNING : duplicate word '9844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,535 : WARNING : duplicate word '4160156' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,538 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,540 : WARNING : duplicate word '562' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,543 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,544 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,545 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,547 : WARNING : duplicate word '8125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,548 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,549 : WARNING : duplicate word '844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,550 : WARNING : duplicate word '906' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,551 : WARNING : duplicate word '9' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,553 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,554 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,555 : WARNING : duplicate word '44' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,556 : WARNING : duplicate word '56' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,557 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,558 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,559 : WARNING : duplicate word '0214844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,561 : WARNING : duplicate word '88' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,562 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,564 : WARNING : duplicate word '88281' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,564 : WARNING : duplicate word '56' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,567 : WARNING : duplicate word '38' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,568 : WARNING : duplicate word '875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,570 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,571 : WARNING : duplicate word '0625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,572 : WARNING : duplicate word '87890625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,573 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,575 : WARNING : duplicate word '156' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,576 : WARNING : duplicate word '69' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,578 : WARNING : duplicate word '44' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,579 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,580 : WARNING : duplicate word '1' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,581 : WARNING : duplicate word '312' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,583 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,585 : WARNING : duplicate word '1875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,586 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,588 : WARNING : duplicate word '9' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,589 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,590 : WARNING : duplicate word '.09716797' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,591 : WARNING : duplicate word '328' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,592 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,593 : WARNING : duplicate word '3' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,594 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,595 : WARNING : duplicate word '85156' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,596 : WARNING : duplicate word '0.123046875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,598 : WARNING : duplicate word '48438' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,600 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,601 : WARNING : duplicate word '6406' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,602 : WARNING : duplicate word '3125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,604 : WARNING : duplicate word '109375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,605 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,607 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,609 : WARNING : duplicate word '537842' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,610 : WARNING : duplicate word '9844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,611 : WARNING : duplicate word '9375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,612 : WARNING : duplicate word '1719' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,612 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,614 : WARNING : duplicate word '812' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,614 : WARNING : duplicate word '92285156' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,616 : WARNING : duplicate word '44' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,617 : WARNING : duplicate word '3594' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,619 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,620 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,621 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,622 : WARNING : duplicate word '531' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,624 : WARNING : duplicate word '906' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,625 : WARNING : duplicate word '73438' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,627 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,628 : WARNING : duplicate word '06' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,630 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,631 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,633 : WARNING : duplicate word '.18847656' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,634 : WARNING : duplicate word '9' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,636 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,637 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,639 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,641 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,642 : WARNING : duplicate word '7' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,643 : WARNING : duplicate word '812' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,644 : WARNING : duplicate word '816406' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,646 : WARNING : duplicate word '516' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,647 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,648 : WARNING : duplicate word '6875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,651 : WARNING : duplicate word '89453' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,652 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,654 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,655 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,657 : WARNING : duplicate word '6308594' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,658 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,659 : WARNING : duplicate word '38' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,662 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,663 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,664 : WARNING : duplicate word '214844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,666 : WARNING : duplicate word '312' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,668 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,669 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,671 : WARNING : duplicate word '047' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,673 : WARNING : duplicate word '0.37304688' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,675 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,676 : WARNING : duplicate word '1875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,681 : WARNING : duplicate word '62' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,683 : WARNING : duplicate word '062' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,685 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,687 : WARNING : duplicate word '06' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,689 : WARNING : duplicate word '7929688' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,690 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,692 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,694 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,695 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,698 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,700 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,702 : WARNING : duplicate word '06933594' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,703 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,705 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,706 : WARNING : duplicate word '69' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,707 : WARNING : duplicate word '062' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,709 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,712 : WARNING : duplicate word '22' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,714 : WARNING : duplicate word '812' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,718 : WARNING : duplicate word '625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,725 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,730 : WARNING : duplicate word '9' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,732 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,737 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,739 : WARNING : duplicate word '3594' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,740 : WARNING : duplicate word '796875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,742 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,743 : WARNING : duplicate word '1' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,745 : WARNING : duplicate word '1562' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,749 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,751 : WARNING : duplicate word '566406' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,752 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,753 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,756 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,757 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,758 : WARNING : duplicate word '6699219' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,761 : WARNING : duplicate word '578' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,763 : WARNING : duplicate word '9375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,766 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,768 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,770 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,772 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,778 : WARNING : duplicate word '88' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,782 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,784 : WARNING : duplicate word '1875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,790 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,796 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,799 : WARNING : duplicate word '359375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,803 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,805 : WARNING : duplicate word '14453125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,807 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,810 : WARNING : duplicate word '96875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,812 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,814 : WARNING : duplicate word '812' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,816 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,819 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,822 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,823 : WARNING : duplicate word '0.07080078' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,825 : WARNING : duplicate word '06' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,827 : WARNING : duplicate word '58594' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,828 : WARNING : duplicate word '3' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,829 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,830 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,832 : WARNING : duplicate word '6406' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,833 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,834 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,837 : WARNING : duplicate word '04345703' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,839 : WARNING : duplicate word '6875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,840 : WARNING : duplicate word '969' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,841 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,843 : WARNING : duplicate word '062' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,844 : WARNING : duplicate word '9375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,845 : WARNING : duplicate word '17' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,847 : WARNING : duplicate word '3125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,848 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,850 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,852 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,854 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,857 : WARNING : duplicate word '0625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,858 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,861 : WARNING : duplicate word '625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,861 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,862 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,864 : WARNING : duplicate word '87890625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,865 : WARNING : duplicate word '1' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,866 : WARNING : duplicate word '84375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,869 : WARNING : duplicate word '06' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,871 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,873 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,878 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,880 : WARNING : duplicate word '06' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,881 : WARNING : duplicate word '062' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,884 : WARNING : duplicate word '7382812' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:33,885 : WARNING : duplicate word '60547' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# ...
# 2018-02-03 07:05:34,655 : WARNING : duplicate word '688' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,657 : WARNING : duplicate word '1875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,658 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,659 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,662 : WARNING : duplicate word '3' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,662 : WARNING : duplicate word '453' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,664 : WARNING : duplicate word '97' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,665 : WARNING : duplicate word '39844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,667 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,668 : WARNING : duplicate word '97' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,670 : WARNING : duplicate word '5625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,672 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,674 : WARNING : duplicate word '4' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,675 : WARNING : duplicate word '9' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,676 : WARNING : duplicate word '35156' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,677 : WARNING : duplicate word '58594' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,679 : WARNING : duplicate word '0078' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,681 : WARNING : duplicate word '9844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,683 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,685 : WARNING : duplicate word '59375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,686 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,688 : WARNING : duplicate word '5126953' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,689 : WARNING : duplicate word '0.08251953' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,691 : WARNING : duplicate word '95312' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,693 : WARNING : duplicate word '4375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,695 : WARNING : duplicate word '0.19335938' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,697 : WARNING : duplicate word '922' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,698 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,700 : WARNING : duplicate word '1719' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,701 : WARNING : duplicate word '1875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,703 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,706 : WARNING : duplicate word '-0.061523438' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,707 : WARNING : duplicate word '472656' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,709 : WARNING : duplicate word '344' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,711 : WARNING : duplicate word '0.05517578' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,713 : WARNING : duplicate word '453125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,714 : WARNING : duplicate word '1' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,715 : WARNING : duplicate word '1' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,717 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,718 : WARNING : duplicate word '777344' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,720 : WARNING : duplicate word '875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,721 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,722 : WARNING : duplicate word '2031' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,724 : WARNING : duplicate word '-0.15625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,726 : WARNING : duplicate word '816406' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,727 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,728 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,731 : WARNING : duplicate word '31' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,734 : WARNING : duplicate word '19' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,736 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,737 : WARNING : duplicate word '88' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,739 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,740 : WARNING : duplicate word '422' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,742 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,743 : WARNING : duplicate word '672' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,745 : WARNING : duplicate word '47' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,746 : WARNING : duplicate word '312' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,747 : WARNING : duplicate word '7812' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,748 : WARNING : duplicate word '484375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,749 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,751 : WARNING : duplicate word '1406' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,752 : WARNING : duplicate word '125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,753 : WARNING : duplicate word '3672' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,756 : WARNING : duplicate word '39844' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,757 : WARNING : duplicate word '0.17382812' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,759 : WARNING : duplicate word '156' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,760 : WARNING : duplicate word '594' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,761 : WARNING : duplicate word '0.25390625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,763 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,765 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,766 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,767 : WARNING : duplicate word '8594' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,769 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,771 : WARNING : duplicate word '92188' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,774 : WARNING : duplicate word '4257812' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,775 : WARNING : duplicate word '8438' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,776 : WARNING : duplicate word '97656' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,778 : WARNING : duplicate word '12' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,779 : WARNING : duplicate word '688' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,780 : WARNING : duplicate word '547' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,781 : WARNING : duplicate word '2' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,782 : WARNING : duplicate word '.15917969' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,784 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,786 : WARNING : duplicate word '75' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,787 : WARNING : duplicate word '047851562' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,789 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,790 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,792 : WARNING : duplicate word '2265625' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,794 : WARNING : duplicate word '5' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,796 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,797 : WARNING : duplicate word '28125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,798 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,800 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,802 : WARNING : duplicate word '31' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,804 : WARNING : duplicate word '7' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,805 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,807 : WARNING : duplicate word '.16210938' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,808 : WARNING : duplicate word '171875' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,810 : WARNING : duplicate word '92285156' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,811 : WARNING : duplicate word '2753906' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,813 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,815 : WARNING : duplicate word '64062' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,816 : WARNING : duplicate word '03125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,817 : WARNING : duplicate word '6' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,819 : WARNING : duplicate word '8' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,821 : WARNING : duplicate word '375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,823 : WARNING : duplicate word '.1328125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,824 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,825 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,827 : WARNING : duplicate word '094' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,828 : WARNING : duplicate word '94' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,829 : WARNING : duplicate word '988281' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,830 : WARNING : duplicate word '9219' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,831 : WARNING : duplicate word '4375' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,832 : WARNING : duplicate word '53906' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,834 : WARNING : duplicate word '9' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,835 : WARNING : duplicate word '25' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,836 : WARNING : duplicate word '60547' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,837 : WARNING : duplicate word '634766' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,839 : WARNING : duplicate word '14453125' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,840 : WARNING : duplicate word '3769531' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,841 : WARNING : duplicate word '' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,844 : WARNING : duplicate word '062' in data/GoogleNews-vectors-negative300.filter, ignoring all but first
# 2018-02-03 07:05:34,845 : INFO : duplicate words detected, shrinking matrix size from 2319 to 1258
# 2018-02-03 07:05:34,847 : INFO : loaded (1258, 300) matrix from data/GoogleNews-vectors-negative300.filter
